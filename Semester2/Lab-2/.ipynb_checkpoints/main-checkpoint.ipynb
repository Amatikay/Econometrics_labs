# %% [markdown]
# - Частные коэффициенты корреляции, проверить наличие статистической связи
# - Множественный коэффициент корреляции
# - Коэффициент детерминации.
#
# Проверить: `Коэффициент детерминации` = `квадрату множественного коэффициента корреляции`.

# %%
data <- read.csv(file = "../Data/Uroshainost.scv", header = TRUE, dec = ",")

# %%
model <- lm(data)

# %%
summary(model)
# Out:
# Call:
# lm(formula = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.4785 -1.3049 -0.5788  0.8404  7.2201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -5.195      9.184  -0.566   0.5806
# X1             3.171      1.798   1.763   0.0996 .
# X2            53.622     36.323   1.476   0.1620
# X3            -2.886      1.609  -1.793   0.0945 .
# X4             3.475      2.617   1.328   0.2055
# X5            -5.205      5.253  -0.991   0.3385
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.7 on 14 degrees of freedom
# Multiple R-squared:  0.3566,	Adjusted R-squared:  0.1268
# F-statistic: 1.552 on 5 and 14 DF,  p-value: 0.237

# %%
cor(data, method = c("pearson")) # Коэффицент корреляции Пирсона
pairs(data,col = "blue")
# Out:
#    Y         X1        X2         X3         X4         X5
# Y  1.0000000 0.3495011 0.33933737 0.28818325 0.30098909 0.2640633
# X1 0.3495011 1.0000000 0.85425359 0.98407983 0.11044360 0.3410126
# X2 0.3393374 0.8542536 1.00000000 0.87939879 0.02685241 0.4595917
# X3 0.2881832 0.9840798 0.87939879 1.00000000 0.06220056 0.2961622
# X4 0.3009891 0.1104436 0.02685241 0.06220056 1.00000000 0.5706292
# X5 0.2640633 0.3410126 0.45959173 0.29616217 0.57062918 1.0000000
# plot without title

# %%
# Статистика стьдента
t <- sqrt(cor(data, method = c("pearson")) * (length(data[,1]) - length(data) - 1)) / sqrt(1 - cor(data)^2)
abs(t)
# Квантиль 95
qt(.975, length(data[,1]) - length(data) - 1)

# H0 отсуствие корреляции. 
# abs(t) < квантиль => H0
# Out:
#    Y        X1        X2        X3         X4        X5
# Y       Inf  2.275024 2.2328146  2.0213109 2.0742842 1.920972
# X1 2.275024       Inf 6.4103477 20.1248858 1.2056103 2.239762
# X2 2.232815  6.410348       Inf  7.1019778 0.5910441 2.752207
# X3 2.021311 20.124886 7.1019778        Inf 0.9009705 2.054331
# X4 2.074284  1.205610 0.5910441  0.9009705       Inf 3.316619
# X5 1.920972  2.239762 2.7522070  2.0543314 3.3166189      Inf
# [1] 2.160369

# %%
solve(cor(data, method = c("pearson"))) # обратная матрица
# Out:
#    Y         X1         X2         X3         X4        X5
# Y   1.554305  -3.626050  -1.319712   4.157081 -0.601209  0.544520
# X1 -3.626050  46.545134   7.563525 -50.230606  1.301415 -4.257322
# X2 -1.319712   7.563525   8.318995 -13.562111  1.994023 -3.175374
# X3  4.157081 -50.230606 -13.562111  59.518739 -2.502630  6.065444
# X4 -0.601209   1.301415   1.994023  -2.502630  2.078943 -1.646599
# X5  0.544520  -4.257322  -3.175374   6.065444 -1.646599  2.910631

# %%
det(cor(data, method = c("pearson")))
# Малое значение определитель опять же указанывает на наличие мультиколлениарности
# Out:
# [1] 0.001529188

# %%
AlgComp <- solve(cor(data, method = c("pearson"))) * det(cor(data, method = c("pearson")))
AlgComp
# Out:
#    Y             X1           X2           X3           X4
# Y   0.0023768240 -0.005544913 -0.002018088  0.006356959 -0.0009193616
# X1 -0.0055449129  0.071176261  0.011566052 -0.076812041  0.0019901076
# X2 -0.0020180881  0.011566052  0.012721307 -0.020739018  0.0030492364
# X3  0.0063569587 -0.076812041 -0.020739018  0.091015343 -0.0038269920
# X4 -0.0009193616  0.001990108  0.003049236 -0.003826992  0.0031790941
# X5  0.0008326735 -0.006510245 -0.004855744  0.009275204 -0.0025179595
#    X5
# Y   0.0008326735
# X1 -0.0065102454
# X2 -0.0048557444
# X3  0.0092752042
# X4 -0.0025179595
# X5  0.0044509015

# %%
# Множ коэф корреляции
MultiplyCor <- 1 - (det(cor(data)) / AlgComp[1,1] )
MultiplyCor
# Out:
# [1] 0.3566255

# %%
#Детерминация
# 1 - Услованя дисперсия/Дисперсия

1 - sum(model$residuals**2) / sum((data$Y - mean(data$Y))**2)
# Out:
# [1] 0.3566255

# %% [markdown]
# # Есть подозрение что, все нужно делать в наборе данных с машинами.

# %%
data <- read.csv(file = "../Data/Cars.csv", header = TRUE, dec = ",")[,-1] # Удалил навзание
head(data)
# Out:
#   CYL  POW LEN WID WT   MAX.SP PRICE
# 1 1350 79  393 161  870 165    30570
# 2 1588 85  468 177 1110 160    39990
# 3 1294 68  424 168 1050 152    29600
# 4 1222 59  412 161  930 151    28250
# 5 1585 98  439 164 1105 165    34900
# 6 1297 82  429 169 1080 160    35480

# %%
model <- lm(PRICE ~ ., data=data)

# %%
summary(model)
# Out:
# Call:
# lm(formula = PRICE ~ ., data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8289.8 -1720.6  -166.6  2913.3  5420.0
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -8239.363  42718.423  -0.193    0.851
# CYL            -3.505      5.551  -0.631    0.541
# POW           282.169    174.883   1.613    0.135
# LEN           -15.038    129.747  -0.116    0.910
# WID           208.694    412.048   0.506    0.623
# WT             12.575     24.622   0.511    0.620
# MAX.SP       -111.114    222.257  -0.500    0.627
#
# Residual standard error: 4406 on 11 degrees of freedom
# Multiple R-squared:  0.7091,	Adjusted R-squared:  0.5504
# F-statistic: 4.469 on 6 and 11 DF,  p-value: 0.0156

# %%
cor(data, method = c("pearson")) # Коэффицент корреляции Пирсона
pairs(data,col = "blue")
# Out:
#        CYL       POW       LEN       WID       WT        MAX.SP    PRICE
# CYL    1.0000000 0.7966277 0.7014619 0.6297572 0.7889520 0.6649340 0.6385812
# POW    0.7966277 1.0000000 0.6413624 0.5208320 0.7652930 0.8443795 0.7987004
# LEN    0.7014619 0.6413624 1.0000000 0.8492664 0.8680903 0.4759285 0.6437569
# WID    0.6297572 0.5208320 0.8492664 1.0000000 0.7168739 0.4729453 0.5466494
# WT     0.7889520 0.7652930 0.8680903 0.7168739 1.0000000 0.4775956 0.7532948
# MAX.SP 0.6649340 0.8443795 0.4759285 0.4729453 0.4775956 1.0000000 0.5817597
# PRICE  0.6385812 0.7987004 0.6437569 0.5466494 0.7532948 0.5817597 1.0000000
# plot without title

# %%
# Статистика стьдента
t <- sqrt(cor(data, method = c("pearson")) * (length(data[,1]) - length(data) - 1)) / sqrt(1 - cor(data)^2)
abs(t)
# Квантиль 95
qt(.975, length(data[,1]) - length(data) - 1)

# H0 отсуствие корреляции. 
# abs(t) < квантиль => H0
# Out:
#        CYL      POW      LEN      WID      WT       MAX.SP   PRICE
# CYL         Inf 4.669311 3.716131 3.230589 4.571254 3.452436 3.283739
# POW    4.669311      Inf 3.300818 2.673402 4.297763 5.423882 4.696681
# LEN    3.716131 3.300818      Inf 5.519721 5.935333 2.480521 3.315652
# WID    3.230589 2.673402 5.519721      Inf 3.840274 2.468222 2.792167
# WT     4.571254 4.297763 5.935333 3.840274      Inf 2.487419 4.173168
# MAX.SP 3.452436 5.423882 2.480521 2.468222 2.487419      Inf 2.965437
# PRICE  3.283739 4.696681 3.315652 2.792167 4.173168 2.965437      Inf
# [1] 2.228139

# %%
solve(cor(data, method = c("pearson"))) # обратная матрица
# Out:
#        CYL        POW        LEN        WID        WT         MAX.SP
# CYL     3.9087620 -1.2933384  0.3471647 -0.5496532 -2.1412945 -0.7884707
# POW    -1.2933384 13.7502326  0.5926508  2.7898662 -6.0730761 -7.7017493
# LEN     0.3471647  0.5926508  7.2129926 -3.2277677 -4.5317412 -0.5744052
# WID    -0.5496532  2.7898662 -3.2277677  4.2954934 -0.6682808 -1.8289276
# WT     -2.1412945 -6.0730761 -4.5317412 -0.6682808 10.1933787  4.6804374
# MAX.SP -0.7884707 -7.7017493 -0.5744052 -1.8289276  4.6804374  6.5199626
# PRICE   0.6856326 -3.0076322  0.1739033 -0.5800915 -0.9008957  0.7056514
#        PRICE
# CYL     0.6856326
# POW    -3.0076322
# LEN     0.1739033
# WID    -0.5800915
# WT     -0.9008957
# MAX.SP  0.7056514
# PRICE   3.4376406

# %%
det(cor(data, method = c("pearson")))
# Малое значение определитель опять же указанывает на наличие мультиколлениарности
# Out:
# [1] 0.0003529692

# %%
AlgComp <- solve(cor(data, method = c("pearson"))) * det(cor(data, method = c("pearson")))
AlgComp
# Out:
#        CYL           POW           LEN           WID           WT
# CYL     0.0013796726 -0.0004565087  1.225385e-04 -0.0001940106 -0.0007558111
# POW    -0.0004565087  0.0048534088  2.091875e-04  0.0009847369 -0.0021436089
# LEN     0.0001225385  0.0002091875  2.545964e-03 -0.0011393026 -0.0015995651
# WID    -0.0001940106  0.0009847369 -1.139303e-03  0.0015161769 -0.0002358826
# WT     -0.0007558111 -0.0021436089 -1.599565e-03 -0.0002358826  0.0035979489
# MAX.SP -0.0002783059 -0.0027184804 -2.027474e-04 -0.0006455551  0.0016520503
# PRICE   0.0002420072 -0.0010616016  6.138253e-05 -0.0002047544 -0.0003179884
#        MAX.SP        PRICE
# CYL    -0.0002783059  2.420072e-04
# POW    -0.0027184804 -1.061602e-03
# LEN    -0.0002027474  6.138253e-05
# WID    -0.0006455551 -2.047544e-04
# WT      0.0016520503 -3.179884e-04
# MAX.SP  0.0023013461  2.490732e-04
# PRICE   0.0002490732  1.213381e-03

# %%
# Множ коэф корреляции
MultiplyCor <- 1 - (det(cor(data)) / AlgComp[7,7] )
MultiplyCor
# Out:
# [1] 0.7091028

# %%
#Детерминация
# 1 - Услованя дисперсия/Дисперсия

1 - sum(model$residuals**2) / sum((data$PRICE - mean(data$PRICE))**2)
# Out:
# [1] 0.7091028

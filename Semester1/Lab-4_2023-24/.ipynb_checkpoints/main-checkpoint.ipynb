# %%
n <- 200
a <- 2
b <- 3
epsilon <- rnorm(n, 0, 1)

# %% [markdown]
# # Часть 1

# %% [markdown]
# $$y_{i} = a + b\,x_{i} ​+ ε_{i}​, \quad ε_{i}​ ∼ N(0,σ^2),\quad i=\overline{1,n}$$

# %%
x <- rnorm(n, 0, .8)
y <- a + b * x + epsilon
plot(y~x)
summary(lm(y ~ x))
abline(lm(y ~ x))
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.62000 -0.58396 -0.04141  0.56083  3.07405
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.91665    0.06729   28.48   <2e-16 ***
# x            3.00555    0.08123   37.00   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9452 on 198 degrees of freedom
# Multiple R-squared:  0.8736,	Adjusted R-squared:  0.873
# F-statistic:  1369 on 1 and 198 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# Для случая `парной линейной регрессии`
# $${\displaystyle {\hat {b}}={\frac {\sum _{t=1}^{n}x_{t}y_{t}}{\sum _{t=1}^{n}x_{t}^{2}}}}$$
# $$ \hat{a} = \overline{y} + \hat{b}\,\overline{x} $$

# %%
b_est <- sum(x,y)/sum(x^2)
a_est <- mean(y) - b_est*mean(x)
a_est
b_est
y_est <- a_est+b_est*x
# Out:
# [1] 1.842943
# [1] 2.234929

# %% [markdown]
# Коэффент детерминации <br>
# $ R^{2} = 1 - \,\frac{RSS}{TSS} $ <br>
# $ RSS = \sum{(y_{i}-\hat{y}_{i})^{2}}$ <br>
# $ TSS = \sum{(y_{i}-\overline{y}_{i})^{2}}$

# %%
RSS <- sum((y-y_est)^2)
TSS <- sum((y-mean(y))^2)
R_2 <- 1- RSS/TSS
RSS
TSS
R_2
# Out:
# [1] 257.3115
# [1] 1400.053
# [1] 0.816213

# %% [markdown]
# Гипотеза о о адкветности модели
# $$ F = \frac{R^2}{1-R^2}\,(n-2)$$

# %%
F <- (R_2/(1-R_2))*(n-2)
F
qf(1 - .05, 1, n-2) #Крит значение статистики
# Out:
# [1] 879.3342
# [1] 3.888853

# %% [markdown]
# Среднеквадратическая ошибка
# $$ S^2 = \frac{1}{n-2} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
# Стандартная ошибка оценки
# $$ S = \sqrt{S^2}$$
# Оценка дисперсии коэффициента наклона:
# $$S^2_{b} = \frac{S^2}{\sum_{i=1}^{n} (x_i - \bar{x})^2}$$
# Стандартная ошибка оценки коэффициента наклона SbSb​:
# $$S_{b} = \sqrt{S^2_{b}}$$
# Оценка дисперсии коэффициента сдвига
# $$S^2_{a} = S^2 \cdot \frac{\bar{x}^2}{\sum_{i=1}^{n} (x_i - \bar{x})^2}$$
# Стандартная ошибка оценки коэффициента сдвига
# $$S_{a} = \sqrt{S^2_{a}}$$
# t-статистика для коэффициента сдвига и наклона:
# $$t = \frac{\text{оцененное значение коэффициента}}{\text{стандартная ошибка оценки коэффициента}}$$

# %%
S2 <- sum((y - y_est)^2) / (n - 2)
SE <- sqrt(S2)
S2_b <- S2 / sum((x - mean(x))^2)
SE_b <- sqrt(S2_b)
S2_a <- S2 * (mean(x^2)) / sum((x - mean(x))^2)
SE_a <- sqrt(S2_a)
t_value_a <- a_est / SE_a
t_value_b <- b_est / SE_b
t_value_a
t_value_b
qt(1 - .05/2, df = n - 2) #квантиль t распределения
# Out:
# [1] 22.70992
# [1] 22.81304
# [1] 1.972017

# %% [markdown]
# # Часть 2

# %% [markdown]
# $$y_{i} = a\,x_{i}^{b}\,ε_{i}​, \quad ln(ε_{i})​ ∼ N(0,σ^2),\quad i=\overline{1,n}$$

# %%
epsilon <- rlnorm(n, 0, .8)
i <- 1:n

# %%
x <- 1+0.1*i
y <- a*(x^b)*epsilon
x <-log(x)
y <-log(y)
plot(y~x)
plot(exp(y)~exp(x))
# Out:
# plot without title
# plot without title

# %%
plot(y~x)
reg <- lm(y~x)
summary(reg)
abline(reg)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.20257 -0.53355  0.04012  0.64884  2.13217
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.40606    0.20532   1.978   0.0493 *
# x            3.11512    0.08866  35.134   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8895 on 198 degrees of freedom
# Multiple R-squared:  0.8618,	Adjusted R-squared:  0.8611
# F-statistic:  1234 on 1 and 198 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# `summary(reg)` выведет значения для линейной модели. Необходимо `exp(Коэффиценты)`

# %%
exp(reg$coefficients)
# Out:
# (Intercept)           x
#    1.500889   22.536038

# %%
b_est <- sum(x,y)/sum(x^2)
a_est <- mean(y) - b_est*mean(x)
a_est
b_est
# Out:
# [1] 3.376924
# [1] 1.767368

# %%
y_est <- a_est+b_est*x
RSS <- sum((y-y_est)^2)
TSS <- sum((y-mean(y))^2)
R_2 <- 1- RSS/TSS
RSS
TSS
R_2
# Out:
# [1] 339.4793
# [1] 1133.332
# [1] 0.700459

# %%
F <- (R_2/(1-R_2))*(n-2)
F
qf(1 - .05, 1, n-2) #Крит значение статистики
# Out:
# [1] 463.0113
# [1] 3.888853

# %%
S2 <- sum((y - y_est)^2) / (n - 2)
SE <- sqrt(S2)
S2_b <- S2 / sum((x - mean(x))^2)
SE_b <- sqrt(S2_b)
S2_a <- S2 * (mean(x^2)) / sum((x - mean(x))^2)
SE_a <- sqrt(S2_a)
t_value_a <- a_est / SE_a
t_value_b <- b_est / SE_b
t_value_a
t_value_b
qt(1 - .05/2, df = n - 2) #квантиль t распределения
# Out:
# [1] 11.17308
# [1] 13.54106
# [1] 1.972017

# %% [markdown]
# # Часть 3

# %% [markdown]
# $$y_{i} = a\,e^{b\,x_{i}}\,ε_{i}​, \quad ln(ε_{i})​ ∼ N(0,σ^2),\quad i=\overline{1,n}$$

# %%
epsilon <- rlnorm(n, 0, .8)
i <- 1:n

# %%
x <- 1 + .04 * i
y <- a * exp(b * x) * epsilon

y <- log(y)

plot(y ~ x)
plot(exp(y) ~ x)
# Out:
# plot without title
# plot without title

# %%
plot(y~x)
reg <- lm(y~x)
summary(reg)
abline(reg)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.20365 -0.55673  0.04224  0.56912  2.52434
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.49877    0.13753   3.627 0.000365 ***
# x            3.03549    0.02489 121.964  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8128 on 198 degrees of freedom
# Multiple R-squared:  0.9869,	Adjusted R-squared:  0.9868
# F-statistic: 1.488e+04 on 1 and 198 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# `summary(reg)` выведет значения для линейной модели. Необходимо `exp(Коэффиценты)`

# %%
exp(reg$coefficients[1])
# Out:
# (Intercept)
#    1.646699

# %%
b_est <- sum(x,y)/sum(x^2)
a_est <- mean(y) - b_est*mean(x)
a_est
b_est
# Out:
# [1] 12.32429
# [1] 0.6798056

# %%
y_est <- a_est+b_est*x
RSS <- sum((y-y_est)^2)
TSS <- sum((y-mean(y))^2)
R_2 <- 1- RSS/TSS
RSS
TSS
R_2
# Out:
# [1] 6049.85
# [1] 9959.026
# [1] 0.392526

# %%
F <- (R_2/(1-R_2))*(n-2)
F
qf(1 - .05, 1, n-2) #Крит значение статистики
# Out:
# [1] 127.9399
# [1] 3.888853

# %%
S2 <- sum((y - y_est)^2) / (n - 2)
SE <- sqrt(S2)
S2_b <- S2 / sum((x - mean(x))^2)
SE_b <- sqrt(S2_b)
S2_a <- S2 * (mean(x^2)) / sum((x - mean(x))^2)
SE_a <- sqrt(S2_a)
t_value_a <- a_est / SE_a
t_value_b <- b_est / SE_b
t_value_a
t_value_b
qt(1 - .05/2, df = n - 2) #квантиль t распределения
# Out:
# [1] 13.17777
# [1] 4.016557
# [1] 1.972017

# %% [markdown]
# # Часть 4

# %% [markdown]
# $$y_{i} = a+\,b\,ln(x_{i})\,+\,ε_{i}​, \quad ε_{i} ∼ N(0,σ^2),\quad i=\overline{1,n}$$

# %%
epsilon <- rnorm(n, 0, .8)
i <- 1:n

# %%
x <- 1 + .1 * i
y <- a + b*log(x) + epsilon
x <- log(x)

plot(y ~ x)
plot(y ~ exp(x))
# Out:
# plot without title
# plot without title

# %%
plot(y~x)
reg <- lm(y~x)
summary(reg)
abline(reg)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.14793 -0.64399  0.08073  0.53172  1.97634
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.05107    0.18842   10.88   <2e-16 ***
# x            2.99667    0.08137   36.83   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8163 on 198 degrees of freedom
# Multiple R-squared:  0.8726,	Adjusted R-squared:  0.872
# F-statistic:  1356 on 1 and 198 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# # Часть 5

# %% [markdown]
# $$y_{i} = a+\, \frac{b}{x_{i}}\,+\,ε_{i}​, \quad ε_{i} ∼ N(0,σ^2),\quad i=\overline{1,n}$$

# %%
a <- .8
b <- 20

# %%
x <- 1 + .1 * i

y <- a + b/x + epsilon

x1 <- 1/x
# Использую новую перменную,не полчается переопределить изначальную. 
# Из за формата хранения числа в компьютере?
plot(y ~ x)
plot(y ~ x1)
# Out:
# plot without title
# plot without title

# %%
plot(y~x1)
reg <- lm(y~x1)
summary(reg)
abline(reg)
# Out:
# Call:
# lm(formula = y ~ x1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.17189 -0.64964  0.08168  0.53864  1.98467
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.82577    0.08136   10.15   <2e-16 ***
# x1          20.11981    0.38267   52.58   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8161 on 198 degrees of freedom
# Multiple R-squared:  0.9332,	Adjusted R-squared:  0.9328
# F-statistic:  2764 on 1 and 198 DF,  p-value: < 2.2e-16
# plot without title
